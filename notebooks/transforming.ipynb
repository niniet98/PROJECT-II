# %% [markdown]
# ### Imports

# %%
import pandas as pd

# %% [markdown]
# ### Reading csv files

# %% [markdown]
#     Original Pixar DataSet

# %%
original_df = pd.read_csv('../data/pixar__studio12.csv')
original_df
# Out:
#               Moviename  Releaseyear  Budget(million)  US and canada(million)  \
# 0             Toy Story         1995              300                    1917
# 1          A Bug's Life         1998             1200                    1628
# 2           Toy Story 2         1999              900                    2459
# 3        Monsters, Inc.         2001             1150                    2899
# 4          Finding Nemo         2003              940                    3397
# 5       The Incredibles         2004              920                    2614
# 6                  Cars         2006             1200                    2441
# 7           Ratatouille         2007             1500                    2064
# 8                WALL-E         2008             1800                    2238
# 9                    Up         2009             1750                    2930
# 10          Toy Story 3         2010             2000                    4150
# ...

# %% [markdown]
# Renaming columns in order to have it standarized in all the dataframes.

# %%
original_df.rename(columns={'Moviename': 'film'}, inplace=True)
original_df.rename(columns={'Releaseyear': 'release_year'}, inplace=True)
original_df.rename(columns={'Budget(million)': 'budget_(million)'}, inplace=True)
original_df.rename(columns={'US and canada(million)': 'us_canada_(million)'}, inplace=True)
original_df.rename(columns={'Other territories(million)': 'other_territories_(million)'}, inplace=True)
original_df.rename(columns={'Worldwide(million)': 'worldwide_(million)'}, inplace=True)
original_df.rename(columns={'Rotten Tomatoes': 'rotten_tomatoes_score'}, inplace=True)
original_df.head(3)
# Out:
#            film  release_year  budget_(million)  us_canada_(million)  \
# 0     Toy Story          1995               300                 1917
# 1  A Bug's Life          1998              1200                 1628
# 2   Toy Story 2          1999               900                 2459
#
#    other_territories_(million)  worldwide_(million) rotten_tomatoes_score
# 0                         1818                 3736                  100%
# 1                         2005                 3633                   92%
# 2                         2515                 4974                  100%

# %% [markdown]
# According to wikipedia information, the budget in this dataframe is 10 times the budget of wikipedia, so it needs to be modified.

# %%
original_df['budget_(million)'] = original_df['budget_(million)'] / 10
original_df['us_canada_(million)'] = original_df['us_canada_(million)'] / 10
original_df['other_territories_(million)'] = original_df['other_territories_(million)'] / 10
original_df['worldwide_(million)'] = original_df['worldwide_(million)'] / 10
original_df.head(3)
# Out:
#            film  release_year  budget_(million)  us_canada_(million)  \
# 0     Toy Story          1995              30.0                191.7
# 1  A Bug's Life          1998             120.0                162.8
# 2   Toy Story 2          1999              90.0                245.9
#
#    other_territories_(million)  worldwide_(million) rotten_tomatoes_score
# 0                        181.8                373.6                  100%
# 1                        200.5                363.3                   92%
# 2                        251.5                497.4                  100%

# %% [markdown]
#     Characters and assets DataSet

# %%
char_assets_df = pd.read_csv('../data/characters_assets.csv')
char_assets_df.head(3)
# Out:
#           film                                         characters  \
# 0    Elemental  Ember Lumen, Wade Ripple, Bernie Lumen, Cinder...
# 1    Lightyear  The Human Side of Buzz, Buzz Lightyear, Izzy H...
# 2  Turning Red  The Inner 13-Year Old, Meilin Lee, Red Panda M...
#
#                                               assets
# 0  Building The World, Firetown, The Water Distri...
# 1  “Warm CGI”, T'kani Prime, Turnip, Star Command...
# 2  “Chunky Cute”, Toronto, Chinatown & the Lee Fa...

# %% [markdown]
#     Academy Awards DataSet

# %%
academy_awards_df = pd.read_csv('../data/pixar_academy_awards.csv')
academy_awards_df.head(3)
# Out:
#            film best_picture          animated_feature original_screenplay  \
# 0     Toy Story          NaN  Award not yet introduced           Nominated
# 1  A Bug's Life          NaN  Award not yet introduced                 NaN
# 2   Toy Story 2          NaN  Award not yet introduced          Ineligible
#
#   adapted_screenplay original_score original_song sound_editing sound_mixing  \
# 0         Ineligible      Nominated     Nominated           NaN          NaN
# 1         Ineligible      Nominated           NaN           NaN          NaN
# 2                NaN            NaN     Nominated           NaN          NaN
#
#                      other
# 0  Won Special Achievement
# 1                      NaN
# 2                      NaN

# %% [markdown]
# ### Merging dataframes

# %%
final_df = pd.merge(original_df, char_assets_df, on="film")
final_df = pd.merge(final_df, academy_awards_df, on="film")
final_df
# Out:
#                    film  release_year  budget_(million)  us_canada_(million)  \
# 0             Toy Story          1995              30.0                191.7
# 1          A Bug's Life          1998             120.0                162.8
# 2           Toy Story 2          1999              90.0                245.9
# 3        Monsters, Inc.          2001             115.0                289.9
# 4          Finding Nemo          2003              94.0                339.7
# 5       The Incredibles          2004              92.0                261.4
# 6                  Cars          2006             120.0                244.1
# 7           Ratatouille          2007             150.0                206.4
# 8                WALL-E          2008             180.0                223.8
# 9                    Up          2009             175.0                293.0
# 10          Toy Story 3          2010             200.0                415.0
# ...
