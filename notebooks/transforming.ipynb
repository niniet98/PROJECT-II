# %% [markdown]
# ### Imports

# %%
import pandas as pd
import re

# %% [markdown]
# ### Reading csv files

# %% [markdown]
#     Original Pixar DataSet

# %%
original_df = pd.read_csv('../data/pixar__studio12.csv')
original_df.sample(3)
# Out:
#         Moviename  Releaseyear  Budget(million)  US and canada(million)  \
# 17         Cars 3         2017             1750                    1529
# 19  Incredibles 2         2018             2000                    6086
# 11         Cars 2         2011             2000                    1915
#
#     Other territories(million)  Worldwide(million) Rotten Tomatoes
# 17                        2310                3839             69%
# 19                        6342               12428             93%
# 11                        3684                5599             40%

# %% [markdown]
# Renaming columns in order to have it standarized in all the dataframes.

# %%
original_df.rename(columns={'Moviename': 'film'}, inplace=True)
original_df.rename(columns={'Releaseyear': 'year'}, inplace=True)
original_df.rename(columns={'Rotten Tomatoes': 'rotten_tomatoes_score'}, inplace=True)
original_df = original_df.drop(columns=['Budget(million)', 'US and canada(million)', 'Other territories(million)', 'Worldwide(million)'])
original_df.head(3)
# Out:
#            film  year rotten_tomatoes_score
# 0     Toy Story  1995                  100%
# 1  A Bug's Life  1998                   92%
# 2   Toy Story 2  1999                  100%

# %% [markdown]
# As the year column is going to be repeated, it has to be removed from this dataframe because as it is not up to date, 4 movies are missing.

# %%
original_df = original_df.drop(columns=['year'])

# %% [markdown]
#     Characters and assets DataSet

# %%
char_assets_df = pd.read_csv('../data/characters_assets.csv')
char_assets_df.head(3)
# Out:
#           film                                         characters  \
# 0    Elemental  Ember Lumen, Wade Ripple, Bernie Lumen, Cinder...
# 1    Lightyear  The Human Side of Buzz, Buzz Lightyear, Izzy H...
# 2  Turning Red  The Inner 13-Year Old, Meilin Lee, Red Panda M...
#
#                                               assets
# 0  Building The World, Firetown, The Water Distri...
# 1  “Warm CGI”, T'kani Prime, Turnip, Star Command...
# 2  “Chunky Cute”, Toronto, Chinatown & the Lee Fa...

# %% [markdown]
#     Academy Awards DataSet

# %%
academy_awards_df = pd.read_csv('../data/pixar_academy_awards.csv')
academy_awards_df.tail(7)
# Out:
#            film best_picture animated_feature original_screenplay  \
# 20  Toy Story 4          NaN              Won          Ineligible
# 21       Onward          NaN        Nominated                 NaN
# 22         Soul          NaN              Won                 NaN
# 23         Luca          NaN        Nominated                 NaN
# 24  Turning Red          NaN        Nominated                 NaN
# 25    Lightyear          NaN              NaN          Ineligible
# 26    Elemental          NaN              NaN                 NaN
#
#    adapted_screenplay original_score original_song sound_editing sound_mixing  \
# 20                NaN            NaN     Nominated           NaN          NaN
# 21         Ineligible            NaN           NaN           NaN          NaN
# 22         Ineligible            Won           NaN     Nominated    Nominated
# 23         Ineligible            NaN           NaN           NaN          NaN
# 24         Ineligible            NaN           NaN           NaN          NaN
# 25                NaN            NaN           NaN           NaN          NaN
# 26                NaN            NaN           NaN           NaN          NaN
#
#    other  year  budget  u.s._and_canada  other_territories  worldwide
# 20   NaN  2019   200.0            434.0                639       1073
# 21   NaN  2020   175.0             62.0                 80        142
# 22   NaN  2020   150.0              NaN                121        121
# 23   NaN  2021     NaN              NaN                 50         50
# 24   NaN  2022   175.0              NaN                 20         20
# 25   NaN  2022   200.0            118.0                108        226
# 26   NaN  2023   200.0            154.0                338        492

# %% [markdown]
# Cleaning Awards DataSet

# %%
def clean_budget(str_):
    rgx = r'\d+'
    res = re.search(rgx, str_)
    if res:
        return int(res.group())
    return ''

def clean_money_cell(str_):
    regex_other = r'\$\d{1,3}(?:,\d{3})*(?:\.\d+)?'
    res = re.search(regex_other, str_)
    if res:
        res = res.group()
        res = res.replace(',', '').replace('$','')
        return round(int(res) / 1000000)
    return ''

academy_awards_df['budget'] = academy_awards_df['budget'].apply(clean_budget)
academy_awards_df['u.s._and_canada'] = academy_awards_df['u.s._and_canada'].apply(clean_money_cell)
academy_awards_df['other_territories'] = academy_awards_df['other_territories'].apply(clean_money_cell)
academy_awards_df['worldwide'] = academy_awards_df['worldwide'].apply(clean_money_cell)

academy_awards_df.tail(7)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\noemi\Documents\IRONHACK\PROJECTS\PROJECT-II\notebooks\transforming.ipynb Cell 15 line 1
#      <a href='vscode-notebook-cell:/c%3A/Users/noemi/Documents/IRONHACK/PROJECTS/PROJECT-II/notebooks/transforming.ipynb#X20sZmlsZQ%3D%3D?line=13'>14</a>         return round(int(res) / 1000000)
#      <a href='vscode-notebook-cell:/c%3A/Users/noemi/Documents/IRONHACK/PROJECTS/PROJECT-II/notebooks/transforming.ipynb#X20sZmlsZQ%3D%3D?line=14'>15</a>     return ''
# ---> <a href='vscode-notebook-cell:/c%3A/Users/noemi/Documents/IRONHACK/PROJECTS/PROJECT-II/notebooks/transforming.ipynb#X20sZmlsZQ%3D%3D?line=16'>17</a> academy_awards_df['budget'] = academy_awards_df['budget'].apply(clean_budget)
#      <a href='vscode-notebook-cell:/c%3A/Users/noemi/Documents/IRONHACK/PROJECTS/PROJECT-II/notebooks/transforming.ipynb#X20sZmlsZQ%3D%3D?line=17'>18</a> academy_awards_df['u.s._and_canada'] = academy_awards_df['u.s._and_canada'].apply(clean_money_cell)
#      <a href='vscode-notebook-cell:/c%3A/Users/noemi/Documents/IRONHACK/PROJECTS/PROJECT-II/notebooks/transforming.ipynb#X20sZmlsZQ%3D%3D?line=18'>19</a> academy_awards_df['other_territories'] = academy_awards_df['other_territories'].apply(clean_money_cell)
#
# File c:\Users\noemi\miniconda3\envs\ironhack\Lib\site-packages\pandas\core\series.py:4760, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4625 def apply(
#    4626     self,
#    4627     func: AggFuncType,
#    (...)
#    4632     **kwargs,
#    4633 ) -> DataFrame | Series:
#    4634     """
#    4635     Invoke function on values of Series.
#    4636
#    (...)
#    4751     dtype: float64
#    4752     """
#    4753     return SeriesApply(
#    4754         self,
#    4755         func,
#    4756         convert_dtype=convert_dtype,
#    4757         by_row=by_row,
#    4758         args=args,
#    4759         kwargs=kwargs,
# -> 4760     ).apply()
#
# File c:\Users\noemi\miniconda3\envs\ironhack\Lib\site-packages\pandas\core\apply.py:1207, in SeriesApply.apply(self)
#    1204     return self.apply_compat()
#    1206 # self.func is Callable
# -> 1207 return self.apply_standard()
#
# File c:\Users\noemi\miniconda3\envs\ironhack\Lib\site-packages\pandas\core\apply.py:1287, in SeriesApply.apply_standard(self)
#    1281 # row-wise access
#    1282 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1283 # we need to give `na_action="ignore"` for categorical data.
#    1284 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1285 #  Categorical (GH51645).
#    1286 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1287 mapped = obj._map_values(
#    1288     mapper=curried, na_action=action, convert=self.convert_dtype
#    1289 )
#    1291 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1292     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1293     #  See also GH#25959 regarding EA support
#    1294     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File c:\Users\noemi\miniconda3\envs\ironhack\Lib\site-packages\pandas\core\base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File c:\Users\noemi\miniconda3\envs\ironhack\Lib\site-packages\pandas\core\algorithms.py:1814, in map_array(arr, mapper, na_action, convert)
#    1812 values = arr.astype(object, copy=False)
#    1813 if na_action is None:
# -> 1814     return lib.map_infer(values, mapper, convert=convert)
#    1815 else:
#    1816     return lib.map_infer_mask(
#    1817         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1818     )
#
# File lib.pyx:2917, in pandas._libs.lib.map_infer()
#
# c:\Users\noemi\Documents\IRONHACK\PROJECTS\PROJECT-II\notebooks\transforming.ipynb Cell 15 line 3
#       <a href='vscode-notebook-cell:/c%3A/Users/noemi/Documents/IRONHACK/PROJECTS/PROJECT-II/notebooks/transforming.ipynb#X20sZmlsZQ%3D%3D?line=0'>1</a> def clean_budget(str_):
#       <a href='vscode-notebook-cell:/c%3A/Users/noemi/Documents/IRONHACK/PROJECTS/PROJECT-II/notebooks/transforming.ipynb#X20sZmlsZQ%3D%3D?line=1'>2</a>     rgx = r'\d+'
# ----> <a href='vscode-notebook-cell:/c%3A/Users/noemi/Documents/IRONHACK/PROJECTS/PROJECT-II/notebooks/transforming.ipynb#X20sZmlsZQ%3D%3D?line=2'>3</a>     res = re.search(rgx, str_)
#       <a href='vscode-notebook-cell:/c%3A/Users/noemi/Documents/IRONHACK/PROJECTS/PROJECT-II/notebooks/transforming.ipynb#X20sZmlsZQ%3D%3D?line=3'>4</a>     if res:
#       <a href='vscode-notebook-cell:/c%3A/Users/noemi/Documents/IRONHACK/PROJECTS/PROJECT-II/notebooks/transforming.ipynb#X20sZmlsZQ%3D%3D?line=4'>5</a>         return int(res.group())
#
# File c:\Users\noemi\miniconda3\envs\ironhack\Lib\re\__init__.py:176, in search(pattern, string, flags)
#     173 def search(pattern, string, flags=0):
#     174     """Scan through string looking for a match to the pattern, returning
#     175     a Match object, or None if no match was found."""
# --> 176     return _compile(pattern, flags).search(string)
#
# TypeError: expected string or bytes-like object, got 'float'

# %% [markdown]
# ### Merging dataframes

# %%
final_df = pd.merge(original_df, char_assets_df, on="film", how="outer")
final_df = pd.merge(final_df, academy_awards_df, on="film", how="outer")
final_df.sample(3)
# Out:
#            film rotten_tomatoes_score  \
# 7   Ratatouille                   96%
# 11       Cars 2                   40%
# 22    Elemental                   NaN
#
#                                            characters  \
# 7   The Artist Rat, Remy, Auguste Gusteau, Linguin...
# 11  What Would Mater Do?, Mater, Lightning McQueen...
# 22  Ember Lumen, Wade Ripple, Bernie Lumen, Cinder...
#
#                                                assets best_picture  \
# 7   A World of Extremes, Old School, Gusteau’s, Li...          NaN
# 11  The International World of Cars 2, (Not) Lost ...          NaN
# 22  Building The World, Firetown, The Water Distri...          NaN
#
#    animated_feature original_screenplay adapted_screenplay original_score  \
# 7               Won           Nominated         Ineligible      Nominated
# 11              NaN          Ineligible                NaN            NaN
# 22              NaN                 NaN                NaN            NaN
#
#    original_song sound_editing sound_mixing other  year budget  \
# 7            NaN     Nominated    Nominated   NaN  2007    150
# 11           NaN           NaN          NaN   NaN  2011    200
# 22           NaN           NaN          NaN   NaN  2023    200
#
#    u.s._and_canada  other_territories  worldwide
# 7              206                417        624
# 11             191                368        560
# 22             154                338        492

# %%
def count_items(str_):
    list_ = str_.split(',')
    return len(list_)

final_df['num_characters'] = final_df['characters'].apply(count_items)
final_df['num_assets'] = final_df['assets'].apply(count_items)
final_df['assets_+_characters'] = final_df['num_characters'] + final_df['num_assets']
final_df.sample(3)
# Out:
#             film rotten_tomatoes_score  \
# 21        Onward                   88%
# 16  Finding Dory                   94%
# 12         Brave                   78%
#
#                                            characters  \
# 21  Ian Lightfoot, Barley Lightfoot, Laurel Lightf...
# 16  The Master Mimic, Dory, Nemo & Marlin, Hank, B...
# 12  The Story of Brave, Merida , Queen Elinor, Kin...
#
#                                                assets best_picture  \
# 21    Familiar Fantasy, Trust Bridge, Homes, Suburbia          NaN
# 16  Water and Light, Great Barrier Reef, The Marin...          NaN
# 12  The Stories of Scotland, Castle DunBroch, The ...          NaN
#
#    animated_feature original_screenplay adapted_screenplay original_score  \
# 21        Nominated                 NaN         Ineligible            NaN
# 16              NaN          Ineligible                NaN            NaN
# 12              Won                 NaN         Ineligible            NaN
#
#    original_song  ... sound_mixing other  year  budget u.s._and_canada  \
# 21           NaN  ...          NaN   NaN  2020     175              62
# 16           NaN  ...          NaN   NaN  2016     200             486
# 12           NaN  ...          NaN   NaN  2012     185             237
#
#    other_territories  worldwide  num_characters  num_assets  \
# 21                80        142               9           4
# 16               542       1029              10           4
# 12               302        539               9           6
#
#     assets_+_characters
# 21                   13
# 16                   14
# 12                   15
#
# [3 rows x 21 columns]

# %%
final_df.to_csv('../data/joined.csv', index=False)
