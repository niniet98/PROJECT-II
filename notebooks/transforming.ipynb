# %% [markdown]
# ### Imports

# %%
import pandas as pd

# %% [markdown]
# ### Reading csv files

# %% [markdown]
#     Original Pixar DataSet

# %%
original_df = pd.read_csv('../data/pixar__studio12.csv')
original_df
# Out:
#               Moviename  Releaseyear  Budget(million)  US and canada(million)  \
# 0             Toy Story         1995              300                    1917
# 1          A Bug's Life         1998             1200                    1628
# 2           Toy Story 2         1999              900                    2459
# 3        Monsters, Inc.         2001             1150                    2899
# 4          Finding Nemo         2003              940                    3397
# 5       The Incredibles         2004              920                    2614
# 6                  Cars         2006             1200                    2441
# 7           Ratatouille         2007             1500                    2064
# 8                WALL-E         2008             1800                    2238
# 9                    Up         2009             1750                    2930
# 10          Toy Story 3         2010             2000                    4150
# 11               Cars 2         2011             2000                    1915
# 12                Brave         2012             1850                    2373
# 13  Monsters University         2013             2000                    2685
# 14           Inside Out         2015             1750                    3565
# 15    The Good Dinosaur         2015             1750                    1231
# 16         Finding Dory         2016             2000                    4863
# 17               Cars 3         2017             1750                    1529
# 18                 Coco         2017             1750                    2097
# 19        Incredibles 2         2018             2000                    6086
# 20          Toy Story 4         2019             2000                    4340
# 21               Onward         2020             2000                     616
#
#     Other territories(million)  Worldwide(million) Rotten Tomatoes
# 0                         1818                3736            100%
# 1                         2005                3633             92%
# 2                         2515                4974            100%
# 3                         3424                6323             96%
# 4                         5313                8710             99%
# 5                         3702                6316             97%
# 6                         2179                4620             74%
# 7                         4173                6237             96%
# 8                         2975                5213             95%
# 9                         4421                7351             98%
# 10                        6520               10670             98%
# 11                        3684                5599             40%
# 12                        3017                5390             78%
# 13                        4751                7436             80%
# 14                        5011                8576             98%
# 15                        2091                3322             76%
# 16                        5423               10286             94%
# 17                        2310                3839             69%
# 18                        5974                8071             97%
# 19                        6342               12428             93%
# 20                        6394               10734             97%
# 21                         804                1420             88%

# %% [markdown]
# Renaming columns in order to have it standarized in all the dataframes.

# %%
original_df.rename(columns={'Moviename': 'film'}, inplace=True)
original_df.rename(columns={'Releaseyear': 'year'}, inplace=True)
original_df.rename(columns={'Budget(million)': 'budget'}, inplace=True)
original_df.rename(columns={'US and canada(million)': 'us_canada'}, inplace=True)
original_df.rename(columns={'Other territories(million)': 'other_territories'}, inplace=True)
original_df.rename(columns={'Worldwide(million)': 'worldwide'}, inplace=True)
original_df.rename(columns={'Rotten Tomatoes': 'rotten_tomatoes_score'}, inplace=True)
original_df.head(3)
# Out:
#            film  year  budget  us_canada  other_territories  worldwide  \
# 0     Toy Story  1995     300       1917               1818       3736
# 1  A Bug's Life  1998    1200       1628               2005       3633
# 2   Toy Story 2  1999     900       2459               2515       4974
#
#   rotten_tomatoes_score
# 0                  100%
# 1                   92%
# 2                  100%

# %% [markdown]
# According to wikipedia information, the budget in this dataframe is 10 times the budget of wikipedia, so it needs to be modified.

# %%
original_df['budget'] = original_df['budget'] / 10
original_df['us_canada'] = original_df['us_canada'] / 10
original_df['other_territories'] = original_df['other_territories'] / 10
original_df['worldwide'] = original_df['worldwide'] / 10
original_df.head(3)
# Out:
#            film  year  budget  us_canada  other_territories  worldwide  \
# 0     Toy Story  1995    30.0      191.7              181.8      373.6
# 1  A Bug's Life  1998   120.0      162.8              200.5      363.3
# 2   Toy Story 2  1999    90.0      245.9              251.5      497.4
#
#   rotten_tomatoes_score
# 0                  100%
# 1                   92%
# 2                  100%

# %% [markdown]
# As the year column is going to be repeated, it has to be removed from this dataframe because as it is not up to date, 4 movies are missing.

# %%
original_df = original_df.drop(columns=['year'])

# %% [markdown]
#     Characters and assets DataSet

# %%
char_assets_df = pd.read_csv('../data/characters_assets.csv')
char_assets_df.head(3)
# Out:
#           film                                         characters  \
# 0    Elemental  Ember Lumen, Wade Ripple, Bernie Lumen, Cinder...
# 1    Lightyear  The Human Side of Buzz, Buzz Lightyear, Izzy H...
# 2  Turning Red  The Inner 13-Year Old, Meilin Lee, Red Panda M...
#
#                                               assets
# 0  Building The World, Firetown, The Water Distri...
# 1  “Warm CGI”, T'kani Prime, Turnip, Star Command...
# 2  “Chunky Cute”, Toronto, Chinatown & the Lee Fa...

# %% [markdown]
#     Academy Awards DataSet

# %%
academy_awards_df = pd.read_csv('../data/pixar_academy_awards.csv')
academy_awards_df.tail(3)
# Out:
#            film best_picture animated_feature original_screenplay  \
# 24  Turning Red          NaN        Nominated                 NaN
# 25    Lightyear          NaN              NaN          Ineligible
# 26    Elemental          NaN              NaN                 NaN
#
#    adapted_screenplay original_score original_song sound_editing sound_mixing  \
# 24         Ineligible            NaN           NaN           NaN          NaN
# 25                NaN            NaN           NaN           NaN          NaN
# 26                NaN            NaN           NaN           NaN          NaN
#
#    other  year
# 24   NaN  2022
# 25   NaN  2022
# 26   NaN  2023

# %% [markdown]
# ### Merging dataframes

# %%
final_df = pd.merge(original_df, char_assets_df, on="film", how="outer")
final_df = pd.merge(final_df, academy_awards_df, on="film", how="outer")
final_df.sample(3)
# Out:
#            film  budget  us_canada  other_territories  worldwide  \
# 26         Soul     NaN        NaN                NaN        NaN
# 2   Toy Story 2    90.0      245.9              251.5      497.4
# 21       Onward   200.0       61.6               80.4      142.0
#
#    rotten_tomatoes_score                                         characters  \
# 26                   NaN  Joe Gardner, 22, Dez, Dorothea Williams , Libb...
# 2                   100%  Woody, Buzz Lightyear, Jessie, Bullseye, Mrs. ...
# 21                   88%  Ian Lightfoot, Barley Lightfoot, Laurel Lightf...
#
#                                                assets best_picture  \
# 26  Building The Performances, New York City, Barb...          NaN
# 2   Al's Apartment, Al's Toy Barn, Woody's Roundup...          NaN
# 21    Familiar Fantasy, Trust Bridge, Homes, Suburbia          NaN
#
#             animated_feature original_screenplay adapted_screenplay  \
# 26                       Won                 NaN         Ineligible
# 2   Award not yet introduced          Ineligible                NaN
# 21                 Nominated                 NaN         Ineligible
#
#    original_score original_song sound_editing sound_mixing other  year
# 26            Won           NaN     Nominated    Nominated   NaN  2020
# 2             NaN     Nominated           NaN          NaN   NaN  1999
# 21            NaN           NaN           NaN          NaN   NaN  2020

# %%
def count_items(str_):
    list_ = str_.split(',')
    return len(list_)

final_df['num_characters'] = final_df['characters'].apply(count_items)
final_df['num_assets'] = final_df['assets'].apply(count_items)

# %%
final_df.to_csv('../data/joined.csv', index=False)
